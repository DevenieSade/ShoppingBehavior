# %% [markdown]
# ## Data Analysis I
#
# Lastly, we will answer the following questions using pandas methods:
#
# * What are the most popular colors by season?
# * What is the most popular clothing item by season?
# * What is the effect of promo-codes on the dollar-amount of purchases?
# * When do users leave a review?
# * Do states vary in the items they purchase in the Fall?
#
# Utilize the documentation provided in each code-block. When you are done with this section of the project, validate that your output matches the screenshot provided in the `docs/part3.md` file and answer the questions located underneath `Data Analysis II` in your own words.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %%
# TODO: load `data/processed/shopping_cleaned.csv` as a pandas dataframe

df_clean = pd.read_csv("../data/processed/shopping_cleaned.csv")

# %%
# TODO: Create a dataframe pivot table where "Season" is your column, "Color" is your index, and "Location" is your value (this value is arbitrary)
# use the len function as the "aggfunc" parameter.
# Save this pivot table to a new variable
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

pivot_table = pd.pivot_table(df_clean, values='Location', index='Color', columns='Season', aggfunc=len)

# %%
# TODO: Display this pivot table

pivot_table
# Out:
# Season                Fall  Spring  Summer  Winter
# Color
# Aubergine             33.0     1.0     5.0    49.0
# Baby blue              9.0    23.0    44.0     7.0
# Black                 36.0     2.0     4.0    54.0
# Brick red             34.0     5.0     6.0    43.0
# Brown                 39.0     1.0     2.0    33.0
# Burnt orange          35.0     NaN     NaN    48.0
# Fuchsia                1.0    20.0    34.0     8.0
# Lavender               6.0    24.0    39.0     3.0
# Lemon yellow           4.0    18.0    38.0     5.0
# Mauve                 31.0     4.0     2.0    41.0
# Muted mustard yellow  41.0     NaN     6.0    41.0
# Pale peach             2.0    21.0    27.0     8.0
# Periwinkle             2.0    16.0    38.0     2.0
# Ruby Red              28.0     1.0     4.0    41.0
# Terra cotta           37.0     2.0     4.0    29.0
# Turquoise              3.0    20.0    32.0     5.0
# White                  3.0    22.0    38.0     5.0

# %%
# TODO: Select the "Fall" column from this pivot table and display the sort order in descending order
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

pivot_table['Fall'].sort_values(ascending=False)
# Out:
# Color
# Muted mustard yellow    41.0
# Brown                   39.0
# Terra cotta             37.0
# Black                   36.0
# Burnt orange            35.0
# Brick red               34.0
# Aubergine               33.0
# Mauve                   31.0
# Ruby Red                28.0
# Baby blue                9.0
# Lavender                 6.0
# Lemon yellow             4.0
# Turquoise                3.0
# White                    3.0
# Periwinkle               2.0
# Pale peach               2.0
# Fuchsia                  1.0
# Name: Fall, dtype: float64

# %%
# TODO: Select the "Winter" column from this pivot table and display the sort order in descending order

winter_column = pivot_table['Winter'].sort_values(ascending=False)
winter_column
# Out:
# Color
# Black                   54.0
# Aubergine               49.0
# Burnt orange            48.0
# Brick red               43.0
# Ruby Red                41.0
# Mauve                   41.0
# Muted mustard yellow    41.0
# Brown                   33.0
# Terra cotta             29.0
# Fuchsia                  8.0
# Pale peach               8.0
# Baby blue                7.0
# Turquoise                5.0
# Lemon yellow             5.0
# White                    5.0
# Lavender                 3.0
# Periwinkle               2.0
# Name: Winter, dtype: float64

# %%
# TODO: Select the "Spring" column from this pivot table and display the sort order in descending order

spring_column = pivot_table['Spring'].sort_values(ascending=False)
spring_column
# Out:
# Color
# Lavender                24.0
# Baby blue               23.0
# White                   22.0
# Pale peach              21.0
# Fuchsia                 20.0
# Turquoise               20.0
# Lemon yellow            18.0
# Periwinkle              16.0
# Brick red                5.0
# Mauve                    4.0
# Black                    2.0
# Terra cotta              2.0
# Aubergine                1.0
# Brown                    1.0
# Ruby Red                 1.0
# Burnt orange             NaN
# Muted mustard yellow     NaN
# Name: Spring, dtype: float64

# %%
# TODO: Select the "Summer" column from this pivot table and display the sort order in descending order

summer_column = pivot_table["Summer"].sort_values(ascending=False)
summer_column
# Out:
# Color
# Baby blue               44.0
# Lavender                39.0
# Lemon yellow            38.0
# Periwinkle              38.0
# White                   38.0
# Fuchsia                 34.0
# Turquoise               32.0
# Pale peach              27.0
# Brick red                6.0
# Muted mustard yellow     6.0
# Aubergine                5.0
# Black                    4.0
# Ruby Red                 4.0
# Terra cotta              4.0
# Brown                    2.0
# Mauve                    2.0
# Burnt orange             NaN
# Name: Summer, dtype: float64

# %%
# TODO: Using the "idmax" method, get the index with the maximum value for each column
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html

pivot_table.idxmax(axis="columns")
# Out:
# Color
# Aubergine               Winter
# Baby blue               Summer
# Black                   Winter
# Brick red               Winter
# Brown                     Fall
# Burnt orange            Winter
# Fuchsia                 Summer
# Lavender                Summer
# Lemon yellow            Summer
# Mauve                   Winter
# Muted mustard yellow      Fall
# Pale peach              Summer
# Periwinkle              Summer
# Ruby Red                Winter
# Terra cotta               Fall
# Turquoise               Summer
# White                   Summer
# dtype: object

# %%
# TODO: Create a dataframe pivot table where "Season" is your column, "Item Purchased" is your index, and "Location" is your value (this value is arbitrary)
# use the len function as the "aggfunc" parameter.
# Save this pivot table to a new variable and display it

new_df = pd.pivot_table(df_clean, values='Location', index='Item Purchased', columns='Season', aggfunc=len)
new_df
# Out:
# Season          Fall  Spring  Summer  Winter
# Item Purchased
# Backpack        22.0     NaN     NaN    37.0
# Belt            10.0     NaN     NaN     NaN
# Boots           22.0     NaN     NaN    40.0
# Dress           11.0    31.0    49.0     NaN
# Gloves          29.0     NaN     NaN    43.0
# Handbag         15.0    26.0    49.0     NaN
# Hoodie          25.0     NaN     NaN    45.0
# Jacket          23.0     NaN     NaN    31.0
# Jeans           10.0     NaN     NaN     NaN
# Leggings        15.0     NaN     NaN    51.0
# Pajamas         21.0     NaN     NaN    45.0
# Running Shoes   15.0    29.0    57.0     NaN
# Scarf           31.0     NaN     NaN    40.0
# Shorts          14.0    33.0    62.0     NaN
# Socks           30.0     NaN     NaN    44.0
# Sunglasses      14.0    35.0    53.0     NaN
# Sweater         32.0     NaN     NaN    46.0
# T-shirt          5.0    26.0    53.0     NaN

# %%
# TODO: Using the "idmax" method, get the index with the maximum value for each column on the pivot table containing clothing items & season
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html

new_df.idxmax(axis="columns")
# Out:
# Item Purchased
# Backpack         Winter
# Belt               Fall
# Boots            Winter
# Dress            Summer
# Gloves           Winter
# Handbag          Summer
# Hoodie           Winter
# Jacket           Winter
# Jeans              Fall
# Leggings         Winter
# Pajamas          Winter
# Running Shoes    Summer
# Scarf            Winter
# Shorts           Summer
# Socks            Winter
# Sunglasses       Summer
# Sweater          Winter
# T-shirt          Summer
# dtype: object

# %%
# TODO: Create two data-frames for promo-code users and non-promo-code users using boolean indexing
# Save these two dataframes into seperate variables 
# Documentation: https://pandas.pydata.org/docs/user_guide/indexing.html#boolean-indexing
# Hint: Users that have used a promo code have the value "Yes" in the column "Promo Code Used"

promo_users = df_clean[df_clean["Promo Code Used"] == 'Yes']

# %%
non_promo_users = df_clean[df_clean['Promo Code Used'] != 'Yes']

# %%
# TODO: Print the shape of the promo code users dataframe. This should be (1373, 13)

promo_users.shape
# Out:
# (0, 16)

# %%
# TODO: Print the average purchase size of promo code users dataframe. This should be 50.06747998236351

promo_users.mean()
# Out:
# Unnamed: 0                NaN
# Customer ID               NaN
# Age                       NaN
# Gender                    NaN
# Item Purchased            NaN
# Purchase Amount (USD)     NaN
# Location                  NaN
# Size                      NaN
# Color                     NaN
# Season                    NaN
# Review Rating             NaN
# Shipping Type             NaN
# Promo Code Used           NaN
# Previous Purchases        NaN
# Payment Method            NaN
# Frequency of Purchases    NaN
# dtype: object

# %%
# TODO: Print the shape of the non promo code users dataframe. This should be (1785, 13)

non_promo_users.shape
# Out:
# (1269,)

# %%
# TODO: Print the average purchase size of non promo code users dataframe. This should be 30.155750765104113


non_promo_users.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: 'MaleFemaleFemaleFemaleMaleFemaleFemaleFemaleMaleMaleFemaleMaleFemaleFemaleFemaleMaleFemaleMaleFemaleMaleFemaleMaleMaleFemaleFemaleMaleMaleMaleMaleFemaleMaleMaleMaleFemaleMaleNon-binaryMaleFemaleFemaleMaleMaleFemaleMaleMaleFemaleFemaleFemaleMaleMaleMaleFemaleFemaleFemaleMaleFemaleMaleFemaleFemaleMaleMaleFemaleFemaleNon-...---...-...-binaryFemaleFemaleFemaleFemaleFemaleMaleMaleFemaleFemaleMaleFemaleFemaleFemaleMaleFemaleFemaleMaleMaleFemaleFemaleMaleFemaleNon-...--...-...-...'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/devenie/Desktop/TKH Projects/shopping-behavior-2/code/03analysis.ipynb Cell 18 line 4
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # TODO: Print the average purchase size of non promo code users dataframe. This should be 30.155750765104113
# ----> <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> non_promo_users.mean()
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1686, in _ensure_numeric(x)
#    1683         x = x.astype(np.float64)
#    1684     except ValueError as err:
#    1685         # GH#29941 we get here with object arrays containing strs
# -> 1686         raise TypeError(f"Could not convert {x} to numeric") from err
#    1687 else:
#    1688     if not np.any(np.imag(x)):
#
# TypeError: Could not convert ['MaleFemaleFemaleFemaleMaleFemaleFemaleFemaleMaleMaleFemaleMaleFemaleFemaleFemaleMaleFemaleMaleFemaleMaleFemaleMaleMaleFemaleFemaleMaleMaleMaleMaleFemaleMaleMaleMaleFemaleMaleNon-binaryMaleFemaleFemaleMaleMaleFemaleMaleMaleFemaleFemaleFemaleMaleMaleMaleFemaleFemaleFemaleMaleFemaleMaleFemaleFemaleMaleMaleFemaleFemaleNon-...---...-...-binaryFemaleFemaleFemaleFemaleFemaleMaleMaleFemaleFemaleMaleFemaleFemaleFemaleMaleFemaleFemaleMaleMaleFemaleFemaleMaleFemaleNon-...--...-...-...'
allyAnnuallyQuarterlyBi-WeeklyMonthlyAnnuallyQuarterlyMonthlyAnnuallyQuarterlyBi-WeeklyQuarterlyQuarterlyAnnuallyMonthlyQuarterlyMonthlyBi-WeeklyAnnuallyAnnuallyMonthlyQuarterlyQuarterlyAnnuallyMonthlyQuarterlyQuarterlyQuarterlyMonthlyMonthlyMonthlyMonthlyAnnuallyMonthlyQuarterlyQuarterlyMonthlyQuarterlyMonthlyMonthlyQuarterlyAnnuallyQuarterlyQuarterlyBi-WeeklyMonthlyMonthlyQuarterlyMonthlyQuarterlyQuarterlyMonthlyQuarterlyQuarterlyQuarterlyMonthlyQuarterlyQuarterlyBi-WeeklyBi-WeeklyQuarterlyQuarterlyAnnuallyQuarterlyAnnuallyAnnuallyMonthlyQuarterlyMonthlyMonthlyQuarterlyQuarterlyBi--WeeklyAnnuallyBi-WeeklyQuarterlyAnnuallyQuarterlyMonthlyQuarterlyMonthlyMonthlyMonthlyQuarterlyQuarterlyBi-WeeklyAnnuallyMonthlyQuarterlyQuarterlyAnnuallyAnnuallyQuarterlyBi-WeeklyQuarterlyWeeklyQuarterlyAnnuallyMonthlyWeeklyQuarterlyQuarterlyQuarterlyBi-WeeklyQuarterlyBi-WeeklyAnnuallyMonthl ...

# %% [markdown]
# Formulate a null hypothesis regarding the dollar amount spent between promo-code users & non-promo-code users

# %% [markdown]
# Answer here

# %% [markdown]
# Formulate an alternative hypothesis regarding the dollar amount spent between promo-code users & non-promo-code users

# %% [markdown]
# Answer here

# %%
# TODO: Using the "ttest_ind" method from "scipy.stats", run a T-Test between the dollar amount spent of promo-code users and non promo-code users
# The t-statistic you should observe is 93.2464714350831
# Documentation: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html

stats.ttest_ind(promo_users, non_promo_users)
# Out:
# TtestResult(statistic=array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan]), pvalue=array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan]), df=array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan]))

# %%
# TODO: Group your dataframe according to the "Review Rating" column. This should produce two groups for the values "Missing" & "Present"
# Save this grouped dataframe into a new variable named "g_review"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

g_review = df_clean.groupby("Review Rating")

# %%
# TODO: Print out the keys of this dataframe for validation. This should output "dict_keys(['Missing', 'Present'])"
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.keys.html

g_review.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/devenie/Desktop/TKH Projects/shopping-behavior-2/code/03analysis.ipynb Cell 25 line 4
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # TODO: Print out the keys of this dataframe for validation. This should output "dict_keys(['Missing', 'Present'])"
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> # Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.keys.html
# ----> <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> g_review.keys()
#
# TypeError: 'str' object is not callable

# %%
# TODO: calculate the average of the "Purchase Amount (USD)", "Age", and "Previous Purchases" columns in our grouped dataframe
# output the values for display
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html
# Documentation: https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html

average_values = g_review.mean()[["Purchase Amount (USD)", "Age", "Previous Purchases"]]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...-...-...--...-...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /Users/devenie/Desktop/TKH Projects/shopping-behavior-2/code/03analysis.ipynb Cell 26 line 6
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # TODO: calculate the average of the "Purchase Amount (USD)", "Age", and "Previous Purchases" columns in our grouped dataframe
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> # output the values for display
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> # Documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html
#       <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> # Documentation: https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
# ----> <a href='vscode-notebook-cell:/Users/devenie/Desktop/TKH%20Projects/shopping-behavior-2/code/03analysis.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a> average_values = g_review.mean()[["Purchase Amount (USD)", "Age", "Previous Purchases"]]
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/internals/managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/internals/blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert ...-...-...--...-... to numeric

# %%
# TODO: Create a new column called "Prev Purchase Group" on your original dataframe which seperates your dataframe into 
# two groups of shoppers based on their "Previous Purchases" column using the "pd.cut" method. 
# Ensure that you are only creating 2 "bins" and label these respective bins as ["Low", "High"]
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.cut.html

df_clean['Prev Purchase Group'] = pd.cut(df_clean['Previous Purchases'], bins=bins, labels=["Low","High"])

# %%
# TODO: Using the "value_counts" function, count how many Missing & Present values are in the "Low" group
# Display this value for analysis 
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
# Hint: You will have to use Boolean Indexing

low_group_counts = df_clean[df_clean['Prev Purchase Group'] == 'Low']['Review Rating'].value_counts()
print(low_group_counts)
# Out:
# Review Rating
# Missing    441
# Present    216
# Name: count, dtype: int64

# %%
# TODO: Using the "value_counts" function, count how many Missing & Present values are in the "High" group
# Display this value for analysis 
# Documentation: https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
# Hint: You will have to use Boolean Indexing

high_group_counts = df_clean[df_clean['Prev Purchase Group'] == 'High']['Review Rating'].value_counts()
print(high_group_counts)
# Out:
# Review Rating
# Missing    349
# Present    263
# Name: count, dtype: int64

# %% [markdown]
# ## Data Analysis II
#
# In the next section, answer the primary analytical questions in your own words.

# %% [markdown]
# ### Q1
#
# What are the top three colors for Fall & Winter?

# %% [markdown]
# The top three colors for Fall are Muted mustard yellow, Broen and Terra Cotta and for Winter are Black, Aubergine and Burnt orange

# %% [markdown]
# ### Q2
#
# What are the top three colors for Spring & Summer?

# %% [markdown]
# The top three colors for Spring are Lavender, Baby blue and White. Summer's to three colors are Baby blue, Lavender and Lemon yellow.

# %% [markdown]
# ### Q3
#
# What is the most popular clothing item by season?

# %% [markdown]
# The most popular clothing item for Fall is both Backpack and Sweater. The most popular clothing item for Winter is Leggings. The most popular clothing item for Spring is Running Shoes. The most popular clothing item for Summer is Shorts

# %% [markdown]
# ### Q4
#
# Observing the p-value that we got when running our t-test between promo-code and non-promo-code users, what can we conclude regarding our null hypothesis?

# %% [markdown]
# Answer here

# %% [markdown]
# ### Q5
#
# Observe the `value_counts` output for the "Review Rating" column for both your "High" and "Low" groups. Proportionally speaking, which group is more likely to leave a review? Why might this be happening from the "human"-perspective? Rationalizations are ok at this point, even if they aren't backed up by data.

# %% [markdown]
# The group that is more likely to leave a review is the high group.From observing the data, the high group is probably more likely to leave a review because they are purchasing more.
